# %% [markdown]
# # Web Scraping  Selenium
# ### LATAM Airlines
# <a href="https://www.latam.com/es_ar/"><img src="https://i.pinimg.com/originals/dd/52/74/dd5274702d1382d696caeb6e0f6980c5.png"  width="420"></img></a>
# <br>

# %% [markdown]
# ### Import Selenium and WebDriver Libraries

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time

url='https://www.latamairlines.com/py/es/ofertas-vuelos?origin=ASU&inbound=null&outbound=2023-02-24T15%3A00%3A00.000Z&destination=MAD&adt=1&chd=0&inf=0&trip=OW&cabin=Economy&redemption=false&sort=RECOMMENDED_A'

# %% [markdown]
# ### Import Explicit Wait libraries

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException

# %% [markdown]
# ### Function to obtain flight prices

# %%
def obtener_precios(vuelo):
    '''
    Funcion que retorna una lista de diccionarios con las distintas tarifas del vuelo
    '''
    tarifas = vuelo.find_elements('xpath','.//ol[@class="sc-buGlAa jhwXGF"]/li')
    precios=[]

    for tarifa in tarifas:
        nombre=tarifa.find_element('xpath','.//div[@class="sc-gGsJSs dhstcp"]/div[1]/span[@class="sc-fhiYOA iwcbaW"]').text
        moneda=tarifa.find_element('xpath','.//div[@class="sc-gGsJSs dhstcp"]/div[3]//span[contains(@class,"currency")]').text
        valor=tarifa.find_element('xpath','.//div[@class="sc-gGsJSs dhstcp"]/div[3]//span[@class="sc-ckYZGd grNCid"]').text

        dict_tarifa={nombre:{'moneda':moneda,'valor':valor}}

        precios.append(dict_tarifa)
    return precios

# %% [markdown]
# ### Function to obtain scale data

# %%
def obtener_datos_escalas(vuelo):
    '''
    Funcion que retorno una lista dédiccionarios con la información de las escalas de cada vuelo
    '''
    segmentos= vuelo.find_elements('xpath','//article[@class="sc-lffWgi vYKpy"]//section[@class="sc-fGSyRc fCuylQ"]')
    datos_escalas=[]
    duracion_escalas_dict={}

    for segmento in segmentos:
        wait_segmento= WebDriverWait(segmento, 15)

        #Origen
        origen_segmento= wait_segmento.until(EC.presence_of_element_located((By.XPATH,'.//div[@class="sc-fguZLD kepXur"]/div[@class="iataCode"]/span[last()-1]'))).text

        #Hora de Salida
        hora_salida= wait_segmento.until(EC.presence_of_element_located((By.XPATH,'.//div[@class="sc-fguZLD kepXur"]/div[@class="iataCode"]/span[2]'))).text

        #Destino Segmento
        destino_segmento= wait_segmento.until(EC.presence_of_element_located((By.XPATH,'.//div[@class="sc-eCXBzT goeYBu"]/div[@class="iataCode"]/span[1]'))).text

        # hora de llegada
        hora_llegada= wait_segmento.until(EC.presence_of_element_located((By.XPATH,'.//div[@class="sc-eCXBzT goeYBu"]/div[@class="iataCode"]/span[2]'))).text

        #duracion del vuelo
        duracion_segmento= wait_segmento.until(EC.presence_of_element_located((By.XPATH,'.//div[@class="sc-ewMkZo hQNSAX"]/span[2]'))).text

        #Numero de vuelo
        numero_vuelo_segmento=wait_segmento.until(EC.presence_of_element_located((By.XPATH,'.//div[@class="sc-dzQEYZ dslPlz airline-wrapper"]'))).text

        #modelo del avion
        modelo_avion_segmento=wait_segmento.until(EC.presence_of_element_located((By.XPATH,'.//div[@class="sc-sVRsr eXYUTi"]//span[@class="airplane-code"]'))).text

        datos_escalas_dict ={
            'origen':origen_segmento,
            'hora_salida':hora_salida,
            'destino':destino_segmento,
            'hora_llegada':hora_llegada,
            'duracion':duracion_segmento,
            'numero_vuelo':numero_vuelo_segmento,
            'modelo_avion':modelo_avion_segmento
        }
        datos_escalas.append(datos_escalas_dict)
    
    #Escalas
    escalas_vuelo= vuelo.find_elements('xpath','//section[@class="sc-kiXyGy sc-eZXMBi dKgCnQ connectionInfo"]')

    for num_escla, escala in enumerate(escalas_vuelo):
        escala_vuelo= escala.find_element('xpath','.//div[@class="sc-ekQYnd cByWfv"]//span[@class="connection-text"]').text
        duracion_escala_vuelo=escala.find_element('xpath','.//div[@class="sc-ekQYnd cByWfv"]//span[@class="time"]').text
        duracion_escalas={
            f'escala_{num_escla+1}':escala_vuelo,
            f'duracion_escala_{num_escla+1}':duracion_escala_vuelo
        }
        duracion_escalas_dict.update(duracion_escalas)
    datos_escalas.append({'duracion_escalas':duracion_escalas_dict})

    return datos_escalas

# %% [markdown]
# ### Function to obtain overall times

# %%
def obtener_tiempos(vuelo):
    '''
    Función que retorna un diccionario con los horarios de salida y llegada de cada vuelo, incluyendo la duracion.
    Nota: la duración del vuelo no es la hora de llegada menos la hora de salida
    '''

    #hora de salida
    hora_salida_vuelo=vuelo.find_element('xpath','.//div[@class="sc-klSiHT hjzFuR flight-information"]/span[1]').text

    #hora de llegada
    hora_llegada_vuelo=vuelo.find_element('xpath','.//div[3]/span[1]').text.replace('\n+1','')

    #duracion del vuelo
    duracion_vuelo=vuelo.find_element('xpath','.//div[2]/span[2]').text

    tiempos_vuelo_dict={
        'hora_salida':hora_salida_vuelo,
        'hora_llegada':hora_llegada_vuelo,
        'duracion_vuelo':duracion_vuelo
    }

    return tiempos_vuelo_dict

# %% [markdown]
# ### Main function that calls the other functions

# %%
def obtener_info(driver):
    '''
    Función principal que se encarga de llamar a las demas funciones para recolectar datos de los vuelos
    '''

    wait=WebDriverWait(driver, 10)
    vuelos=wait.until(EC.presence_of_all_elements_located((By.XPATH,'//ol/li[@class="sc-bvTASY cfqKKq"]')))

    print(f'Se encontraron {len(vuelos)} vuelos')
    print(f'Iniciando Scraping...')
    count=0
    info=[]
    
    for vuelo in vuelos:
        count+=1
        print(f'Analizando {count} de {len(vuelos)} vuelos')

        #Tiempos generales del vuelo
        tiempos= obtener_tiempos(vuelo)

        #Modal de vuelos internos o escalas
        WebDriverWait(vuelo,10).until(EC.presence_of_element_located((By.XPATH, './/div[@class="sc-iKiVwC fbWfQZ"]//a'))).click()

        element= vuelo.find_element('xpath','//div[@class="MuiDialogContent-root sc-bZQynM hnBdls"]')
        vertical_ordinate=100
        for i in range(0, 10):
            driver.execute_script("arguments[0].scrollTop = arguments[1]", element, vertical_ordinate)
            vertical_ordinate += 100
            time.sleep(1)

        print('Termino de cargar las escalas del vuelo')

        escalas=obtener_datos_escalas(vuelo)
        print(f'{escalas}\n')

        driver.find_element('xpath','//div[@class="MuiDialog-container MuiDialog-scrollPaper"]').click()

        vuelo.find_element('xpath','.//div[@class="sc-cIbcTr iuAYhf"]').click()

        WebDriverWait(driver,15).until(EC.presence_of_all_elements_located((By.XPATH,'.//ol[@class="sc-buGlAa jhwXGF"]/li')))

        print('La tabla de precios termino de cargar')

        precios=obtener_precios(vuelo)
        print(f'{precios}\n\n')

        vuelo.find_element('xpath','.//div[@id="undefined--button-wrapper"]/button').click()

        info.append({
            'precios':precios,
            'tiempos':tiempos,
            'escalas':escalas
        })
    
    return info

# %% [markdown]
# ### We initialize driver and call the main function

# %%
options = Options()

options.add_argument('--incognito')

driver = webdriver.Chrome(options=options)
driver.maximize_window()
driver.get(url)

def close_dialog():
    '''
    Función que cierra los dialog o popups de la pagina web
    '''

    dialogs=driver.find_elements(By.XPATH,'//div[contains(@class,"MuiDialog-container")]')
    if len(dialogs):
        dialogs[0].find_element(By.XPATH,'.//button[contains(@class,"Dialog__CloseButton")]').click()

close_dialog()

delay=15

try:
    WebDriverWait(driver, delay).until(EC.presence_of_all_elements_located((By.XPATH, '//div[@id="WrapperBodyFlights"]//ol/li[@class="sc-bvTASY cfqKKq"]')))
    print('Los vuelos disponibles terminaron de cargar')
    obtener_info(driver)
except TimeoutException:
    print('La página tardó demasiado en cargar')
finally:
    driver.close()
# Out:
# Los vuelos disponibles terminaron de cargar
# Se encontraron 30 vuelos
# Iniciando Scraping...
# Analizando 1 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '10:50 a. m.', 'destino': 'SCL', 'hora_llegada': '1:40 p. m.', 'duracion': '2 h 50 min', 'numero_vuelo': 'LA1324', 'modelo_avion': 'Airbus A320'}, {'origen': 'SCL', 'hora_salida': '5:10 p. m.', 'destino': 'GRU', 'hora_llegada': '8:55 p. m.', 'duracion': '3 h 45 min', 'numero_vuelo': 'LA702', 'modelo_avion': 'Boeing B787-8'}, {'origen': 'GRU', 'hora_salida': '11:30 p. m.', 'destino': 'MAD', 'hora_llegada': '1:25 p. m.', 'duracion': '9 h 55 min', 'numero_vuelo': 'LA8066', 'modelo_avion': 'Boeing B787-9'}, {'duracion_escalas': {'escala_1': 'Conexión Santiago de Chile', 'duracion_escala_1': '3 h 30 min', 'escala_2': 'Conexión Sao Paulo', 'duracion_escala_2': '2 h 35 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '799.80'}}, {'plus': {'moneda': 'USD', 'valor': '898.80'}}, {'top': {'moneda': 'USD', 'valor': '1,001.80'}}, {'top': {'moneda': 'USD', 'valor': '2,891.80'}}]
#
#
# Analizando 2 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '6:35 p. m.', 'destino': 'GRU', 'hora_llegada': '8:45 p. m.', 'duracion': '2 h 10 min', 'numero_vuelo': 'LA1301', 'modelo_avion': 'Airbus A320'}, {'origen': 'GRU', 'hora_salida': '11:30 p. m.', 'destino': 'MAD', 'hora_llegada': '1:25 p. m.', 'duracion': '9 h 55 min', 'numero_vuelo': 'LA8066', 'modelo_avion': 'Boeing B787-9'}, {'duracion_escalas': {'escala_1': 'Conexión Sao Paulo', 'duracion_escala_1': '2 h 45 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '1,041.80'}}, {'plus': {'moneda': 'USD', 'valor': '1,161.80'}}, {'top': {'moneda': 'USD', 'valor': '1,284.80'}}, {'top': {'moneda': 'USD', 'valor': '2,891.80'}}]
#
#
# Analizando 3 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '10:50 a. m.', 'destino': 'SCL', 'hora_llegada': '1:40 p. m.', 'duracion': '2 h 50 min', 'numero_vuelo': 'LA1324', 'modelo_avion': 'Airbus A320'}, {'origen': 'SCL', 'hora_salida': '5:35 p. m.', 'destino': 'LIM', 'hora_llegada': '7:20 p. m.', 'duracion': '3 h 45 min', 'numero_vuelo': 'LA2696', 'modelo_avion': 'Boeing B787-9'}, {'origen': 'LIM', 'hora_salida': '10:55 p. m.', 'destino': 'MAD', 'hora_llegada': '4:20 p. m.', 'duracion': '11 h 25 min', 'numero_vuelo': 'LA2484', 'modelo_avion': 'Boeing B787-9'}, {'duracion_escalas': {'escala_1': 'Conexión Santiago de Chile', 'duracion_escala_1': '3 h 55 min', 'escala_2': 'Conexión Lima', 'duracion_escala_2': '3 h 35 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '837.80'}}, {'plus': {'moneda': 'USD', 'valor': '941.80'}}, {'top': {'moneda': 'USD', 'valor': '1,049.80'}}, {'top': {'moneda': 'USD', 'valor': '3,034.80'}}]
#
#
# Analizando 4 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '10:50 a. m.', 'destino': 'SCL', 'hora_llegada': '1:40 p. m.', 'duracion': '2 h 50 min', 'numero_vuelo': 'LA1324', 'modelo_avion': 'Airbus A320'}, {'origen': 'SCL', 'hora_salida': '3:10 p. m.', 'destino': 'LIM', 'hora_llegada': '5:00 p. m.', 'duracion': '3 h 50 min', 'numero_vuelo': 'LA2414', 'modelo_avion': 'Airbus A320'}, {'origen': 'LIM', 'hora_salida': '10:55 p. m.', 'destino': 'MAD', 'hora_llegada': '4:20 p. m.', 'duracion': '11 h 25 min', 'numero_vuelo': 'LA2484', 'modelo_avion': 'Boeing B787-9'}, {'duracion_escalas': {'escala_1': 'Conexión Santiago de Chile', 'duracion_escala_1': '1 h 30 min', 'escala_2': 'Conexión Lima', 'duracion_escala_2': '5 h 55 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '837.80'}}, {'plus': {'moneda': 'USD', 'valor': '941.80'}}, {'top': {'moneda': 'USD', 'valor': '1,049.80'}}, {'top': {'moneda': 'USD', 'valor': '3,034.80'}}]
#
#
# Analizando 5 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '10:50 a. m.', 'destino': 'SCL', 'hora_llegada': '1:40 p. m.', 'duracion': '2 h 50 min', 'numero_vuelo': 'LA1324', 'modelo_avion': 'Airbus A320'}, {'origen': 'SCL', 'hora_salida': '9:20 p. m.', 'destino': 'MAD', 'hora_llegada': '1:55 p. m.', 'duracion': '12 h 35 min', 'numero_vuelo': 'LA706', 'modelo_avion': 'Boeing B787-9'}, {'duracion_escalas': {'escala_1': 'Conexión Santiago de Chile', 'duracion_escala_1': '7 h 40 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '1,041.80'}}, {'plus': {'moneda': 'USD', 'valor': '1,161.80'}}, {'top': {'moneda': 'USD', 'valor': '1,284.80'}}]
#
#
# Analizando 6 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '2:20 a. m.', 'destino': 'GRU', 'hora_llegada': '4:15 a. m.', 'duracion': '1 h 55 min', 'numero_vuelo': 'LA1303', 'modelo_avion': 'Airbus A320'}, {'origen': 'GRU', 'hora_salida': '2:45 p. m.', 'destino': 'SCL', 'hora_llegada': '7:06 p. m.', 'duracion': '4 h 21 min', 'numero_vuelo': 'LA759', 'modelo_avion': 'Airbus A321'}, {'origen': 'SCL', 'hora_salida': '9:20 p. m.', 'destino': 'MAD', 'hora_llegada': '1:55 p. m.', 'duracion': '12 h 35 min', 'numero_vuelo': 'LA706', 'modelo_avion': 'Boeing B787-9'}, {'duracion_escalas': {'escala_1': 'Conexión Sao Paulo', 'duracion_escala_1': '10 h 30 min', 'escala_2': 'Conexión Santiago de Chile', 'duracion_escala_2': '2 h 14 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '2,169.80'}}, {'plus': {'moneda': 'USD', 'valor': '2,403.80'}}, {'top': {'moneda': 'USD', 'valor': '2,663.80'}}, {'top': {'moneda': 'USD', 'valor': '3,319.80'}}]
#
#
# Analizando 7 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '2:20 a. m.', 'destino': 'GRU', 'hora_llegada': '4:15 a. m.', 'duracion': '1 h 55 min', 'numero_vuelo': 'LA1303', 'modelo_avion': 'Airbus A320'}, {'origen': 'GRU', 'hora_salida': '12:25 p. m.', 'destino': 'SCL', 'hora_llegada': '4:45 p. m.', 'duracion': '4 h 20 min', 'numero_vuelo': 'LA757', 'modelo_avion': 'Airbus A320'}, {'origen': 'SCL', 'hora_salida': '9:20 p. m.', 'destino': 'MAD', 'hora_llegada': '1:55 p. m.', 'duracion': '12 h 35 min', 'numero_vuelo': 'LA706', 'modelo_avion': 'Boeing B787-9'}, {'duracion_escalas': {'escala_1': 'Conexión Sao Paulo', 'duracion_escala_1': '8 h 10 min', 'escala_2': 'Conexión Santiago de Chile', 'duracion_escala_2': '4 h 35 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '2,169.80'}}, {'plus': {'moneda': 'USD', 'valor': '2,403.80'}}, {'top': {'moneda': 'USD', 'valor': '2,663.80'}}]
#
#
# Analizando 8 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '2:20 a. m.', 'destino': 'GRU', 'hora_llegada': '4:15 a. m.', 'duracion': '1 h 55 min', 'numero_vuelo': 'LA1303', 'modelo_avion': 'Airbus A320'}, {'origen': 'GRU', 'hora_salida': '6:55 a. m.', 'destino': 'SCL', 'hora_llegada': '11:05 a. m.', 'duracion': '4 h 10 min', 'numero_vuelo': 'LA701', 'modelo_avion': 'Boeing B787-8'}, {'origen': 'SCL', 'hora_salida': '9:20 p. m.', 'destino': 'MAD', 'hora_llegada': '1:55 p. m.', 'duracion': '12 h 35 min', 'numero_vuelo': 'LA706', 'modelo_avion': 'Boeing B787-9'}, {'duracion_escalas': {'escala_1': 'Conexión Sao Paulo', 'duracion_escala_1': '2 h 40 min', 'escala_2': 'Conexión Santiago de Chile', 'duracion_escala_2': '10 h 15 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '2,169.80'}}, {'plus': {'moneda': 'USD', 'valor': '2,403.80'}}, {'top': {'moneda': 'USD', 'valor': '2,663.80'}}]
#
#
# Analizando 9 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '6:35 p. m.', 'destino': 'GRU', 'hora_llegada': '8:45 p. m.', 'duracion': '2 h 10 min', 'numero_vuelo': 'LA1301', 'modelo_avion': 'Airbus A320'}, {'origen': 'GRU', 'hora_salida': '6:55 a. m.', 'destino': 'SCL', 'hora_llegada': '11:05 a. m.', 'duracion': '4 h 10 min', 'numero_vuelo': 'LA701', 'modelo_avion': 'Boeing B787-8'}, {'origen': 'SCL', 'hora_salida': '9:20 p. m.', 'destino': 'MAD', 'hora_llegada': '1:55 p. m.', 'duracion': '12 h 35 min', 'numero_vuelo': 'LA706', 'modelo_avion': 'Boeing B787-8'}, {'duracion_escalas': {'escala_1': 'Conexión Sao Paulo', 'duracion_escala_1': '10 h 10 min', 'escala_2': 'Conexión Santiago de Chile', 'duracion_escala_2': '10 h 15 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '2,169.80'}}, {'plus': {'moneda': 'USD', 'valor': '2,403.80'}}, {'top': {'moneda': 'USD', 'valor': '2,663.80'}}]
#
#
# Analizando 10 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '6:25 a. m.', 'destino': 'AEP', 'hora_llegada': '8:15 a. m.', 'duracion': '1 h 50 min', 'numero_vuelo': 'LA6015', 'modelo_avion': 'CRJ-200'}, {'origen': 'AEP', 'hora_salida': '4:55 p. m.', 'destino': 'LIM', 'hora_llegada': '7:30 p. m.', 'duracion': '4 h 35 min', 'numero_vuelo': 'LA2433', 'modelo_avion': 'Airbus A320'}, {'origen': 'LIM', 'hora_salida': '9:10 p. m.', 'destino': 'MAD', 'hora_llegada': '2:30 p. m.', 'duracion': '11 h 20 min', 'numero_vuelo': 'LA5391', 'modelo_avion': 'Airbus A350-900'}, {'duracion_escalas': {'escala_1': 'Conexión Buenos Aires', 'duracion_escala_1': '8 h 40 min', 'escala_2': 'Conexión Lima', 'duracion_escala_2': '1 h 40 min'}}]
#
# La tabla de precios termino de cargar
# [{'plus': {'moneda': 'USD', 'valor': '893.20'}}, {'top': {'moneda': 'USD', 'valor': '3,321.20'}}]
#
#
# Analizando 11 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '2:20 a. m.', 'destino': 'GRU', 'hora_llegada': '4:15 a. m.', 'duracion': '1 h 55 min', 'numero_vuelo': 'LA1303', 'modelo_avion': 'Airbus A320'}, {'origen': 'GRU', 'hora_salida': '3:40 p. m.', 'destino': 'MAD', 'hora_llegada': '6:00 a. m.', 'duracion': '10 h 20 min', 'numero_vuelo': 'LA7107', 'modelo_avion': 'Airbus A330'}, {'duracion_escalas': {'escala_1': 'Conexión Sao Paulo', 'duracion_escala_1': '11 h 25 min'}}]
#
# La tabla de precios termino de cargar
# [{'plus': {'moneda': 'USD', 'valor': '898.80'}}, {'top': {'moneda': 'USD', 'valor': '2,891.80'}}]
#
#
# Analizando 12 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '6:25 a. m.', 'destino': 'AEP', 'hora_llegada': '8:15 a. m.', 'duracion': '1 h 50 min', 'numero_vuelo': 'LA6015', 'modelo_avion': 'CRJ-200'}, {'origen': 'AEP', 'hora_salida': '11:35 a. m.', 'destino': 'GRU', 'hora_llegada': '2:15 p. m.', 'duracion': '2 h 40 min', 'numero_vuelo': 'LA8033', 'modelo_avion': 'Airbus A320'}, {'origen': 'GRU', 'hora_salida': '3:40 p. m.', 'destino': 'MAD', 'hora_llegada': '6:00 a. m.', 'duracion': '10 h 20 min', 'numero_vuelo': 'LA7107', 'modelo_avion': 'Airbus A330'}, {'duracion_escalas': {'escala_1': 'Conexión Buenos Aires', 'duracion_escala_1': '3 h 20 min', 'escala_2': 'Conexión Sao Paulo', 'duracion_escala_2': '1 h 25 min'}}]
#
# La tabla de precios termino de cargar
# [{'plus': {'moneda': 'USD', 'valor': '900.20'}}, {'top': {'moneda': 'USD', 'valor': '2,893.20'}}]
#
#
# Analizando 13 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '6:25 a. m.', 'destino': 'AEP', 'hora_llegada': '8:15 a. m.', 'duracion': '1 h 50 min', 'numero_vuelo': 'LA6015', 'modelo_avion': 'CRJ-200'}, {'origen': 'AEP', 'hora_salida': '4:55 p. m.', 'destino': 'LIM', 'hora_llegada': '7:30 p. m.', 'duracion': '4 h 35 min', 'numero_vuelo': 'LA2433', 'modelo_avion': 'Airbus A320'}, {'origen': 'LIM', 'hora_salida': '10:55 p. m.', 'destino': 'MAD', 'hora_llegada': '4:20 p. m.', 'duracion': '11 h 25 min', 'numero_vuelo': 'LA2484', 'modelo_avion': 'Boeing B787-9'}, {'duracion_escalas': {'escala_1': 'Conexión Buenos Aires', 'duracion_escala_1': '8 h 40 min', 'escala_2': 'Conexión Lima', 'duracion_escala_2': '3 h 25 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '915.20'}}, {'plus': {'moneda': 'USD', 'valor': '1,029.20'}}, {'top': {'moneda': 'USD', 'valor': '1,147.20'}}, {'top': {'moneda': 'USD', 'valor': '3,321.20'}}]
#
#
# Analizando 14 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '2:20 a. m.', 'destino': 'GRU', 'hora_llegada': '4:15 a. m.', 'duracion': '1 h 55 min', 'numero_vuelo': 'LA1303', 'modelo_avion': 'Airbus A320'}, {'origen': 'GRU', 'hora_salida': '6:50 a. m.', 'destino': 'LIM', 'hora_llegada': '9:50 a. m.', 'duracion': '5 h', 'numero_vuelo': 'LA2693', 'modelo_avion': 'Boeing B767-300'}, {'origen': 'LIM', 'hora_salida': '9:10 p. m.', 'destino': 'MAD', 'hora_llegada': '2:30 p. m.', 'duracion': '11 h 20 min', 'numero_vuelo': 'LA5391', 'modelo_avion': 'Airbus A350-900'}, {'duracion_escalas': {'escala_1': 'Conexión Sao Paulo', 'duracion_escala_1': '2 h 35 min', 'escala_2': 'Conexión Lima', 'duracion_escala_2': '11 h 20 min'}}]
#
# La tabla de precios termino de cargar
# [{'plus': {'moneda': 'USD', 'valor': '928.80'}}, {'top': {'moneda': 'USD', 'valor': '3,461.80'}}]
#
#
# Analizando 15 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '4:55 p. m.', 'destino': 'MVD', 'hora_llegada': '6:45 p. m.', 'duracion': '1 h 50 min', 'numero_vuelo': 'LA6018', 'modelo_avion': 'CRJ-200'}, {'origen': 'MVD', 'hora_salida': '7:25 a. m.', 'destino': 'LIM', 'hora_llegada': '10:25 a. m.', 'duracion': '5 h', 'numero_vuelo': 'LA2421', 'modelo_avion': 'Airbus A320'}, {'origen': 'LIM', 'hora_salida': '9:10 p. m.', 'destino': 'MAD', 'hora_llegada': '2:30 p. m.', 'duracion': '11 h 20 min', 'numero_vuelo': 'LA5391', 'modelo_avion': 'Airbus A350-900'}, {'duracion_escalas': {'escala_1': 'Conexión Montevideo', 'duracion_escala_1': '12 h 40 min', 'escala_2': 'Conexión Lima', 'duracion_escala_2': '10 h 45 min'}}]
#
# La tabla de precios termino de cargar
# [{'plus': {'moneda': 'USD', 'valor': '937.27'}}, {'top': {'moneda': 'USD', 'valor': '3,470.27'}}]
#
#
# Analizando 16 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '6:25 a. m.', 'destino': 'AEP', 'hora_llegada': '8:15 a. m.', 'duracion': '1 h 50 min', 'numero_vuelo': 'LA6015', 'modelo_avion': 'CRJ-200'}, {'origen': 'AEP', 'hora_salida': '6:40 p. m.', 'destino': 'GRU', 'hora_llegada': '9:15 p. m.', 'duracion': '2 h 35 min', 'numero_vuelo': 'LA8035', 'modelo_avion': 'Airbus A320'}, {'origen': 'GRU', 'hora_salida': '11:30 p. m.', 'destino': 'MAD', 'hora_llegada': '1:25 p. m.', 'duracion': '9 h 55 min', 'numero_vuelo': 'LA8066', 'modelo_avion': 'Boeing B787-9'}, {'duracion_escalas': {'escala_1': 'Conexión Buenos Aires', 'duracion_escala_1': '10 h 25 min', 'escala_2': 'Conexión Sao Paulo', 'duracion_escala_2': '2 h 15 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '1,043.20'}}, {'plus': {'moneda': 'USD', 'valor': '1,163.20'}}, {'top': {'moneda': 'USD', 'valor': '1,286.20'}}, {'top': {'moneda': 'USD', 'valor': '2,893.20'}}]
#
#
# Analizando 17 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '6:25 a. m.', 'destino': 'AEP', 'hora_llegada': '8:15 a. m.', 'duracion': '1 h 50 min', 'numero_vuelo': 'LA6015', 'modelo_avion': 'CRJ-200'}, {'origen': 'AEP', 'hora_salida': '11:35 a. m.', 'destino': 'GRU', 'hora_llegada': '2:15 p. m.', 'duracion': '2 h 40 min', 'numero_vuelo': 'LA8033', 'modelo_avion': 'Airbus A320'}, {'origen': 'GRU', 'hora_salida': '11:30 p. m.', 'destino': 'MAD', 'hora_llegada': '1:25 p. m.', 'duracion': '9 h 55 min', 'numero_vuelo': 'LA8066', 'modelo_avion': 'Boeing B787-9'}, {'duracion_escalas': {'escala_1': 'Conexión Buenos Aires', 'duracion_escala_1': '3 h 20 min', 'escala_2': 'Conexión Sao Paulo', 'duracion_escala_2': '9 h 15 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '1,043.20'}}, {'plus': {'moneda': 'USD', 'valor': '1,163.20'}}, {'top': {'moneda': 'USD', 'valor': '1,286.20'}}, {'top': {'moneda': 'USD', 'valor': '2,893.20'}}]
#
#
# Analizando 18 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '6:25 a. m.', 'destino': 'AEP', 'hora_llegada': '8:15 a. m.', 'duracion': '1 h 50 min', 'numero_vuelo': 'LA6015', 'modelo_avion': 'CRJ-200'}, {'origen': 'EZE', 'hora_salida': '3:50 p. m.', 'destino': 'SCL', 'hora_llegada': '6:10 p. m.', 'duracion': '2 h 20 min', 'numero_vuelo': 'LA450', 'modelo_avion': 'Airbus A320'}, {'origen': 'SCL', 'hora_salida': '9:20 p. m.', 'destino': 'MAD', 'hora_llegada': '1:55 p. m.', 'duracion': '12 h 35 min', 'numero_vuelo': 'LA706', 'modelo_avion': 'Boeing B787-9'}, {'duracion_escalas': {'escala_1': 'Conexión Buenos Aires', 'duracion_escala_1': '7 h 35 min', 'escala_2': 'Conexión Santiago de Chile', 'duracion_escala_2': '3 h 10 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '1,043.20'}}, {'plus': {'moneda': 'USD', 'valor': '1,163.20'}}, {'top': {'moneda': 'USD', 'valor': '1,286.20'}}, {'top': {'moneda': 'USD', 'valor': '2,893.20'}}]
#
#
# Analizando 19 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '6:25 a. m.', 'destino': 'AEP', 'hora_llegada': '8:15 a. m.', 'duracion': '1 h 50 min', 'numero_vuelo': 'LA6015', 'modelo_avion': 'CRJ-200'}, {'origen': 'AEP', 'hora_salida': '1:00 p. m.', 'destino': 'SCL', 'hora_llegada': '3:16 p. m.', 'duracion': '2 h 16 min', 'numero_vuelo': 'LA420', 'modelo_avion': 'Airbus A320'}, {'origen': 'SCL', 'hora_salida': '9:20 p. m.', 'destino': 'MAD', 'hora_llegada': '1:55 p. m.', 'duracion': '12 h 35 min', 'numero_vuelo': 'LA706', 'modelo_avion': 'Boeing B787-9'}, {'duracion_escalas': {'escala_1': 'Conexión Buenos Aires', 'duracion_escala_1': '4 h 45 min', 'escala_2': 'Conexión Santiago de Chile', 'duracion_escala_2': '6 h 4 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '1,043.20'}}, {'plus': {'moneda': 'USD', 'valor': '1,163.20'}}, {'top': {'moneda': 'USD', 'valor': '1,286.20'}}, {'top': {'moneda': 'USD', 'valor': '2,893.20'}}]
#
#
# Analizando 20 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '6:35 p. m.', 'destino': 'GRU', 'hora_llegada': '8:45 p. m.', 'duracion': '2 h 10 min', 'numero_vuelo': 'LA1301', 'modelo_avion': 'Airbus A320'}, {'origen': 'GRU', 'hora_salida': '11:50 p. m.', 'destino': 'LHR', 'hora_llegada': '1:55 p. m.', 'duracion': '11 h 5 min', 'numero_vuelo': 'LA8084', 'modelo_avion': 'Boeing B777-300'}, {'origen': 'LHR', 'hora_salida': '3:45 p. m.', 'destino': 'MAD', 'hora_llegada': '7:15 p. m.', 'duracion': '2 h 30 min', 'numero_vuelo': 'LA1542', 'modelo_avion': 'Airbus A320'}, {'duracion_escalas': {'escala_1': 'Conexión Sao Paulo', 'duracion_escala_1': '3 h 5 min', 'escala_2': 'Conexión Londres', 'duracion_escala_2': '1 h 50 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '1,113.30'}}, {'plus': {'moneda': 'USD', 'valor': '1,239.30'}}, {'top': {'moneda': 'USD', 'valor': '1,368.30'}}, {'top': {'moneda': 'USD', 'valor': '3,056.30'}}]
#
#
# Analizando 21 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '6:35 p. m.', 'destino': 'GRU', 'hora_llegada': '8:45 p. m.', 'duracion': '2 h 10 min', 'numero_vuelo': 'LA1301', 'modelo_avion': 'Airbus A320'}, {'origen': 'GRU', 'hora_salida': '11:50 p. m.', 'destino': 'LHR', 'hora_llegada': '1:55 p. m.', 'duracion': '11 h 5 min', 'numero_vuelo': 'LA8084', 'modelo_avion': 'Boeing B777-300'}, {'origen': 'LHR', 'hora_salida': '5:10 p. m.', 'destino': 'MAD', 'hora_llegada': '8:40 p. m.', 'duracion': '2 h 30 min', 'numero_vuelo': 'LA1541', 'modelo_avion': 'Airbus A320'}, {'duracion_escalas': {'escala_1': 'Conexión Sao Paulo', 'duracion_escala_1': '3 h 5 min', 'escala_2': 'Conexión Londres', 'duracion_escala_2': '3 h 15 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '1,113.30'}}, {'plus': {'moneda': 'USD', 'valor': '1,239.30'}}, {'top': {'moneda': 'USD', 'valor': '1,368.30'}}, {'top': {'moneda': 'USD', 'valor': '3,056.30'}}]
#
#
# Analizando 22 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '5:40 p. m.', 'destino': 'AEP', 'hora_llegada': '7:30 p. m.', 'duracion': '1 h 50 min', 'numero_vuelo': 'LA6012', 'modelo_avion': 'CRJ-200'}, {'origen': 'EZE', 'hora_salida': '5:10 a. m.', 'destino': 'SCL', 'hora_llegada': '7:30 a. m.', 'duracion': '2 h 20 min', 'numero_vuelo': 'LA472', 'modelo_avion': 'Airbus A320'}, {'origen': 'SCL', 'hora_salida': '1:20 p. m.', 'destino': 'MAD', 'hora_llegada': '6:00 a. m.', 'duracion': '12 h 40 min', 'numero_vuelo': 'LA5410', 'modelo_avion': 'Airbus A350-900'}, {'duracion_escalas': {'escala_1': 'Conexión Buenos Aires', 'duracion_escala_1': '9 h 40 min', 'escala_2': 'Conexión Santiago de Chile', 'duracion_escala_2': '5 h 50 min'}}]
#
# La tabla de precios termino de cargar
# [{'plus': {'moneda': 'USD', 'valor': '1,163.20'}}]
#
#
# Analizando 23 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '10:50 a. m.', 'destino': 'SCL', 'hora_llegada': '1:40 p. m.', 'duracion': '2 h 50 min', 'numero_vuelo': 'LA1324', 'modelo_avion': 'Airbus A320'}, {'origen': 'SCL', 'hora_salida': '5:35 p. m.', 'destino': 'LIM', 'hora_llegada': '7:20 p. m.', 'duracion': '3 h 45 min', 'numero_vuelo': 'LA2696', 'modelo_avion': 'Boeing B787-9'}, {'origen': 'LIM', 'hora_salida': '9:10 p. m.', 'destino': 'MAD', 'hora_llegada': '2:30 p. m.', 'duracion': '11 h 20 min', 'numero_vuelo': 'LA5391', 'modelo_avion': 'Airbus A350-900'}, {'duracion_escalas': {'escala_1': 'Conexión Santiago de Chile', 'duracion_escala_1': '3 h 55 min', 'escala_2': 'Conexión Lima', 'duracion_escala_2': '1 h 50 min'}}]
#
# La tabla de precios termino de cargar
# [{'plus': {'moneda': 'USD', 'valor': '1,217.80'}}]
#
#
# Analizando 24 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '10:50 a. m.', 'destino': 'SCL', 'hora_llegada': '1:40 p. m.', 'duracion': '2 h 50 min', 'numero_vuelo': 'LA1324', 'modelo_avion': 'Airbus A320'}, {'origen': 'SCL', 'hora_salida': '3:10 p. m.', 'destino': 'LIM', 'hora_llegada': '5:00 p. m.', 'duracion': '3 h 50 min', 'numero_vuelo': 'LA2414', 'modelo_avion': 'Airbus A320'}, {'origen': 'LIM', 'hora_salida': '9:10 p. m.', 'destino': 'MAD', 'hora_llegada': '2:30 p. m.', 'duracion': '11 h 20 min', 'numero_vuelo': 'LA5391', 'modelo_avion': 'Airbus A350-900'}, {'duracion_escalas': {'escala_1': 'Conexión Santiago de Chile', 'duracion_escala_1': '1 h 30 min', 'escala_2': 'Conexión Lima', 'duracion_escala_2': '4 h 10 min'}}]
#
# La tabla de precios termino de cargar
# [{'plus': {'moneda': 'USD', 'valor': '1,217.80'}}, {'top': {'moneda': 'USD', 'valor': '3,034.80'}}]
#
#
# Analizando 25 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '4:55 p. m.', 'destino': 'MVD', 'hora_llegada': '6:45 p. m.', 'duracion': '1 h 50 min', 'numero_vuelo': 'LA6018', 'modelo_avion': 'CRJ-200'}, {'origen': 'MVD', 'hora_salida': '7:25 a. m.', 'destino': 'LIM', 'hora_llegada': '10:25 a. m.', 'duracion': '5 h', 'numero_vuelo': 'LA2421', 'modelo_avion': 'Airbus A320'}, {'origen': 'LIM', 'hora_salida': '10:55 p. m.', 'destino': 'MAD', 'hora_llegada': '4:20 p. m.', 'duracion': '11 h 25 min', 'numero_vuelo': 'LA2484', 'modelo_avion': 'Boeing B787-9'}, {'duracion_escalas': {'escala_1': 'Conexión Montevideo', 'duracion_escala_1': '12 h 40 min', 'escala_2': 'Conexión Lima', 'duracion_escala_2': '12 h 30 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '1,250.27'}}, {'plus': {'moneda': 'USD', 'valor': '1,394.27'}}, {'top': {'moneda': 'USD', 'valor': '1,542.27'}}, {'top': {'moneda': 'USD', 'valor': '3,470.27'}}]
#
#
# Analizando 26 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '10:50 a. m.', 'destino': 'SCL', 'hora_llegada': '1:40 p. m.', 'duracion': '2 h 50 min', 'numero_vuelo': 'LA1324', 'modelo_avion': 'Airbus A320'}, {'origen': 'SCL', 'hora_salida': '4:00 p. m.', 'destino': 'BOG', 'hora_llegada': '8:05 p. m.', 'duracion': '6 h 5 min', 'numero_vuelo': 'LA576', 'modelo_avion': 'Boeing B787-8'}, {'origen': 'BOG', 'hora_salida': '10:25 p. m.', 'destino': 'MAD', 'hora_llegada': '2:15 p. m.', 'duracion': '9 h 50 min', 'numero_vuelo': 'LA1575', 'modelo_avion': 'Airbus A350-900'}, {'duracion_escalas': {'escala_1': 'Conexión Santiago de Chile', 'duracion_escala_1': '2 h 20 min', 'escala_2': 'Conexión Bogotá', 'duracion_escala_2': '2 h 20 min'}}]
#
# La tabla de precios termino de cargar
# [{'plus': {'moneda': 'USD', 'valor': '1,273.80'}}]
#
#
# Analizando 27 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '2:20 a. m.', 'destino': 'GRU', 'hora_llegada': '4:15 a. m.', 'duracion': '1 h 55 min', 'numero_vuelo': 'LA1303', 'modelo_avion': 'Airbus A320'}, {'origen': 'GRU', 'hora_salida': '2:50 p. m.', 'destino': 'BOG', 'hora_llegada': '6:50 p. m.', 'duracion': '6 h', 'numero_vuelo': 'LA8000', 'modelo_avion': 'Airbus A320'}, {'origen': 'BOG', 'hora_salida': '10:25 p. m.', 'destino': 'MAD', 'hora_llegada': '2:15 p. m.', 'duracion': '9 h 50 min', 'numero_vuelo': 'LA1575', 'modelo_avion': 'Airbus A350-900'}, {'duracion_escalas': {'escala_1': 'Conexión Sao Paulo', 'duracion_escala_1': '10 h 35 min', 'escala_2': 'Conexión Bogotá', 'duracion_escala_2': '3 h 35 min'}}]
#
# La tabla de precios termino de cargar
# [{'plus': {'moneda': 'USD', 'valor': '1,385.80'}}, {'top': {'moneda': 'USD', 'valor': '3,461.80'}}]
#
#
# Analizando 28 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '6:35 p. m.', 'destino': 'GRU', 'hora_llegada': '8:45 p. m.', 'duracion': '2 h 10 min', 'numero_vuelo': 'LA1301', 'modelo_avion': 'Airbus A320'}, {'origen': 'GRU', 'hora_salida': '10:50 p. m.', 'destino': 'CDG', 'hora_llegada': '2:05 p. m.', 'duracion': '11 h 15 min', 'numero_vuelo': 'LA702', 'modelo_avion': 'Boeing B787-8'}, {'origen': 'ORY', 'hora_salida': '5:20 p. m.', 'destino': 'MAD', 'hora_llegada': '7:25 p. m.', 'duracion': '2 h 5 min', 'numero_vuelo': 'LA1554', 'modelo_avion': 'Airbus A320'}, {'duracion_escalas': {'escala_1': 'Conexión Sao Paulo', 'duracion_escala_1': '2 h 5 min', 'escala_2': 'Conexión París', 'duracion_escala_2': '3 h 15 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '1,397.90'}}, {'plus': {'moneda': 'USD', 'valor': '1,559.90'}}, {'top': {'moneda': 'USD', 'valor': '1,725.90'}}, {'top': {'moneda': 'USD', 'valor': '3,046.90'}}]
#
#
# Analizando 29 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '6:35 p. m.', 'destino': 'GRU', 'hora_llegada': '8:45 p. m.', 'duracion': '2 h 10 min', 'numero_vuelo': 'LA1301', 'modelo_avion': 'Airbus A320'}, {'origen': 'GRU', 'hora_salida': '10:50 p. m.', 'destino': 'CDG', 'hora_llegada': '2:05 p. m.', 'duracion': '11 h 15 min', 'numero_vuelo': 'LA702', 'modelo_avion': 'Boeing B787-8'}, {'origen': 'ORY', 'hora_salida': '7:25 p. m.', 'destino': 'MAD', 'hora_llegada': '9:30 p. m.', 'duracion': '2 h 5 min', 'numero_vuelo': 'LA5441', 'modelo_avion': 'Airbus A320'}, {'duracion_escalas': {'escala_1': 'Conexión Sao Paulo', 'duracion_escala_1': '2 h 5 min', 'escala_2': 'Conexión París', 'duracion_escala_2': '5 h 20 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '1,397.90'}}, {'plus': {'moneda': 'USD', 'valor': '1,559.90'}}, {'top': {'moneda': 'USD', 'valor': '1,725.90'}}, {'top': {'moneda': 'USD', 'valor': '3,046.90'}}]
#
#
# Analizando 30 de 30 vuelos
# Termino de cargar las escalas del vuelo
# [{'origen': 'ASU', 'hora_salida': '5:40 p. m.', 'destino': 'AEP', 'hora_llegada': '7:30 p. m.', 'duracion': '1 h 50 min', 'numero_vuelo': 'LA6012', 'modelo_avion': 'CRJ-200'}, {'origen': 'EZE', 'hora_salida': '7:35 a. m.', 'destino': 'LIM', 'hora_llegada': '10:25 a. m.', 'duracion': '4 h 50 min', 'numero_vuelo': 'LA1436', 'modelo_avion': 'Airbus A319'}, {'origen': 'LIM', 'hora_salida': '10:55 p. m.', 'destino': 'MAD', 'hora_llegada': '4:20 p. m.', 'duracion': '11 h 25 min', 'numero_vuelo': 'LA2484', 'modelo_avion': 'Boeing B787-9'}, {'duracion_escalas': {'escala_1': 'Conexión Buenos Aires', 'duracion_escala_1': '12 h 5 min', 'escala_2': 'Conexión Lima', 'duracion_escala_2': '12 h 30 min'}}]
#
# La tabla de precios termino de cargar
# [{'light': {'moneda': 'USD', 'valor': '1,525.20'}}, {'plus': {'moneda': 'USD', 'valor': '1,702.20'}}, {'top': {'moneda': 'USD', 'valor': '1,884.20'}}, {'top': {'moneda': 'USD', 'valor': '3,331.20'}}]
